# %% [markdown]
# # Laboratory 5 instruction part 2 - MLflow
#
# In machine learning development, one of the most challenging aspects is maintaining reproducibility. This issue is particularly relevant to the experimental phase, when a lot of small, but influential code changes are constantly introduced.
#
# After extensive experimentation with different model architectures, hyperparameters, and preprocessing techniques, researchers often find themselves unable to recreate their best-performing models because critical configuration details were not properly recorded.

# %% [markdown]
# ## MLflow
#
# [MLflow is an open-source platform](https://mlflow.org/) that addresses this challenge by providing systematic experiment tracking throughout the machine learning lifecycle. It automatically captures configurations, metrics, and artifacts from each model training run, transforming ad-hoc model development into a structured, reproducible process. In this notebook, we will learn how to use MLflow to properly track experiments for both traditional machine learning and deep learning workflows.

# %% [markdown]
# ### Learning objectives
#
# 1. **Implement automated experiment tracking** using MLflow autologging capabilities with scikit-learn, enabling automatic capture of model parameters and metrics without writing additional tracking code.
#
# 2. **Configure manual logging strategies** for PyTorch experiments, implementing custom tracking for metrics, parameters, and artifacts throughout the training process.
#
# 3. **Analyze and compare experimental results** using MLflow tracking UI and programmatic APIs to identify optimal model configurations and understand performance patterns.

# %% [markdown]
# ### Laboratory plan
#
# 1. **MLflow tracking server** configuration and deployment for experiment management
# 2. **Automatic logging mechanisms** for scikit-learn experiments
# 3. **Manual logging implementation** for PyTorch deep learning workflows
# 4. **Hyperparameter optimization exercise** - systematic hyperparameter exploration
# 5. **Best practices** for experiment organization, versioning, and cross-team reproducibility

# %% [markdown]
# ## 1. MLflow Tracking server configuration

# %% [markdown]
# [MLflow Tracking](https://mlflow.org/docs/latest/tracking/) is the main component of MLflow, responsible for capturing, storing, and presenting metrics, logs, and other tracking data. MLflow is based on a client-server architecture, where the central MLflow server can serve potentially whole teams of data scientists. You can also simply run it as a local server from the commandline, as we will now.

# %% [markdown]
# 1. Create a directory for MLflow artifacts storage:
# ```bash
# mkdir mlflow-artifacts
# ```
#
# 2. Start the MLflow tracking server:
# ```bash
# mlflow server \
#   --backend-store-uri sqlite:///mlflow.db \
#   --default-artifact-root ./mlflow-artifacts \
#   --host 0.0.0.0 \
#   --port 5555
# ```
# Important: Keep this terminal window open. The MLflow server will continue running and be accessible at http://localhost:5555

# %% [markdown]
# To verify if the server runs properly, let's connect to git:

# %%
import mlflow
import mlflow.sklearn

import warnings

warnings.filterwarnings("ignore")

mlflow.set_tracking_uri("http://localhost:5555")
print(f"Connected to MLflow at: {mlflow.get_tracking_uri()}")
# Out:
# Connected to MLflow at: http://localhost:5555

# %% [markdown]
# Setup complete! You now have the MLflow server running as a separate process, and `mlflow` library in this Jupyter Notebook is connected to it. Just note that we had to use the proper host and port - if you want to connect to a remote server, modify the tracking URI appropriately.

# %% [markdown]
# ## 2. Automatic logging with scikit-learn

# %% [markdown]
# ### 2.1 Dataset preparation
#
# In this section, we'll use the Ames Housing dataset to demonstrate MLflow's autologging capabilities with scikit-learn. Since we have already prepared the 2006-2008 data using DVC, we can use our preprocessed dataset here. As we have temporal data, the best way to evaluate our model is time (chronological) split, where the newest data is used for testing. We will assume that we have the data for years 2006 and 2007, and evaluate using data from 2008.

# %%
import numpy as np
import pandas as pd

from feature_engine.encoding import RareLabelEncoder
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import MinMaxScaler, OneHotEncoder

# %%
df = pd.read_parquet("data/ames_data_2006_2008.parquet")

df = df.sort_values(by=["YrSold"])

df_train = df[df["YrSold"] < 2008]
df_test = df[df["YrSold"] == 2008]

y_train = df_train.pop("SalePrice")
y_test = df_test.pop("SalePrice")

categorical_features = df_train.select_dtypes(include="object").columns
numerical_features = df_train.select_dtypes(exclude="object").columns

# %%
median_imputer = SimpleImputer(strategy="median")
min_max_scaler = MinMaxScaler()
rare_encoder = RareLabelEncoder(tol=0.01, n_categories=0)
one_hot_encoder = OneHotEncoder(
    drop="first", sparse_output=False, handle_unknown="ignore"
)

num_pipeline = Pipeline(
    [("median_imputer", median_imputer), ("min_max_scaler", min_max_scaler)]
)

cat_pipeline = Pipeline(
    [("rare_encoder", rare_encoder), ("one_hot_encoder", one_hot_encoder)]
)

column_transformer = ColumnTransformer(
    [
        ("num_pipeline", num_pipeline, numerical_features),
        ("cat_pipeline", cat_pipeline, categorical_features),
    ],
    verbose_feature_names_out=False,
)
column_transformer.fit(df_train)

X_train = column_transformer.transform(df_train)
X_test = column_transformer.transform(df_test)

# %%
print(f"Training samples: {X_train.shape[0]}")
print(f"Test samples: {X_test.shape[0]}")
print(f"Number of features: {X_train.shape[1]}")
# Out:
# Training samples: 1312
# Test samples: 621
# Number of features: 181

# %% [markdown]
# ### 2.2 Training with MLflow autologging

# %% [markdown]
# Autologging is a powerful built-in capability of MLflow, enabling fully automated and near-zero code integration of MLflow with many popular frameworks. In particular, it works really well with scikit-learn, thanks to its highly unified API. Let's try this out - we will enable autologging, and then train a buch of different models.

# %%
mlflow.sklearn.autolog(
    log_input_examples=True, log_model_signatures=True, log_models=False, silent=False
)

mlflow.set_experiment("ames-housing-autolog")
# Out:
# 2025/11/18 21:03:06 INFO mlflow.tracking.fluent: Experiment with name 'ames-housing-autolog' does not exist. Creating a new experiment.
# <Experiment: artifact_location='/Users/karol/Studia/sem9/ml-ops-lab05/mlflow-artifacts/1', creation_time=1763496186879, experiment_id='1', last_update_time=1763496186879, lifecycle_stage='active', name='ames-housing-autolog', tags={}>

# %%
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.linear_model import Ridge
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor

models = [
    ("Ridge Regression", Ridge()),
    ("Decision Tree", DecisionTreeRegressor(max_depth=10, random_state=42)),
    ("K-Nearest Neighbors", KNeighborsRegressor(n_neighbors=10)),
    ("Random Forest", RandomForestRegressor(n_estimators=100, random_state=42)),
    ("Gradient Boosting", GradientBoostingRegressor(n_estimators=100, random_state=42)),
]

# %%
from sklearn.metrics import root_mean_squared_error, mean_absolute_error, r2_score


def fit_sklearn_models_with_cv(models, X_train, X_test, y_train, y_test):
    results = {}

    for model_name, model in models:
        # start MLflow run - a unit grouping logs from different model runs
        # everything within this context manager will get logged as a run
        with mlflow.start_run(run_name=model_name):
            model.fit(X_train, y_train.to_numpy())

            y_pred = model.predict(X_test)

            rmse = root_mean_squared_error(y_test, y_pred)
            mae = mean_absolute_error(y_test, y_pred)
            r2 = r2_score(y_test, y_pred)

            cv_scores = cross_val_score(
                model, X_train, y_train.to_numpy(), cv=5, scoring="r2"
            )
            cv_mean = cv_scores.mean()
            cv_std = cv_scores.std()

            # log additional custom metrics, in addition to autologging
            mlflow.log_metric("cv_r2_mean", cv_mean)
            mlflow.log_metric("cv_r2_std", cv_std)

            results[model_name] = {
                "rmse": rmse,
                "mae": mae,
                "r2": r2,
                "cv_r2_mean": cv_mean,
            }

            print(f"\n{model_name}:")
            print(f"  RMSE: {rmse:.2f}")
            print(f"  MAE: {mae:.2f}")
            print(f"  R^2: {r2:.3f}")
            print(f"  CV R^2 (mean ± std): {cv_mean:.3f} ± {cv_std:.3f}")

# %%
fit_sklearn_models_with_cv(models, X_train, X_test, y_train, y_test)
# Out:
# Ridge Regression:
#   RMSE: 23450.39
#   MAE: 16430.79
#   R^2: 0.904
#   CV R^2 (mean ± std): 0.895 ± 0.035
# 🏃 View run Ridge Regression at: http://localhost:5555/#/experiments/1/runs/aa11182342fc4a33a5bdf0c454137430
# 🧪 View experiment at: http://localhost:5555/#/experiments/1
#
# Decision Tree:
#   RMSE: 36860.51
#   MAE: 23270.66
#   R^2: 0.762
#   CV R^2 (mean ± std): 0.755 ± 0.057
# 🏃 View run Decision Tree at: http://localhost:5555/#/experiments/1/runs/205acb2afad74663b760b222936650d9
# 🧪 View experiment at: http://localhost:5555/#/experiments/1
#
# K-Nearest Neighbors:
#   RMSE: 38324.60
#   MAE: 26033.27
#   R^2: 0.743
#   CV R^2 (mean ± std): 0.691 ± 0.049
# 🏃 View run K-Nearest Neighbors at: http://localhost:5555/#/experiments/1/runs/138f1b07c9eb47eba1dece3c08be9305
# 🧪 View experiment at: http://localhost:5555/#/experiments/1
#
# Random Forest:
#   RMSE: 25814.13
#   MAE: 15606.16
#   R^2: 0.883
#   CV R^2 (mean ± std): 0.879 ± 0.049
# 🏃 View run Random Forest at: http://localhost:5555/#/experiments/1/runs/3087720597284efb8bae158c855d85d0
# 🧪 View experiment at: http://localhost:5555/#/experiments/1
#
# Gradient Boosting:
#   RMSE: 21600.50
#   MAE: 13840.01
#   R^2: 0.918
#   CV R^2 (mean ± std): 0.904 ± 0.031
# 🏃 View run Gradient Boosting at: http://localhost:5555/#/experiments/1/runs/04876efa59414a5e9a7d32164a4a9fb7
# 🧪 View experiment at: http://localhost:5555/#/experiments/1

# %% [markdown]
# Open the MLflow dashboard at http://localhost:5000/ and go to the Experiments tab. On the left, you have the experiment name, and when you select it, the list of all experiments will show up. Click through the interface and familiarize yourself with the most important elements:
#
# 1. What columns can be selected
# 2. Pick a particular run and check what values are logged automatically
# 3. Select columns to compare a given metric between runs, e.g. MAE
# 4. Sort algorithms by the selected metric to pick the best one

# %% [markdown]
# ### Exercise 1

# %% [markdown]
# We have trained 5 different models. The results of all of them can now be compared in MLflow. Since we obtained quite satisfactory results, our imaginary client would like to be sure that we do our best and wants us to compare many more combinations.
#
# Your task is to run 5 more experiments with different parameters and models from scikit-learn. You can use any [supervised learning methods from scikit-learn](https://scikit-learn.org/stable/supervised_learning.html). Find some other models or parameters to tune our current models with and run the experiments again. Use the function `fit_sklearn_models_with_cv()` created above, or you can write your own if you want.
#
# Did you manage to beat the previous approaches?

# %%
from sklearn.ensemble import ExtraTreesRegressor, HistGradientBoostingRegressor
from sklearn.linear_model import ElasticNet, Lasso
from sklearn.svm import SVR

advanced_models = [
    ("Hist Gradient Boosting", HistGradientBoostingRegressor(random_state=42)),
    (
        "Extra Trees",
        ExtraTreesRegressor(n_estimators=200, max_depth=15, random_state=42),
    ),
    ("ElasticNet", ElasticNet(alpha=0.001, l1_ratio=0.5, random_state=42)),
    ("Lasso Regression", Lasso(alpha=0.0005, random_state=42)),
    ("SVR (Linear)", SVR(kernel="linear", C=1.0)),
]

fit_sklearn_models_with_cv(advanced_models, X_train, X_test, y_train, y_test)
# Out:
# Hist Gradient Boosting:
#   RMSE: 22857.71
#   MAE: 14258.98
#   R^2: 0.909
#   CV R^2 (mean ± std): 0.901 ± 0.039
# 🏃 View run Hist Gradient Boosting at: http://localhost:5555/#/experiments/1/runs/71b0856d88824b78bf8982440060e7c2
# 🧪 View experiment at: http://localhost:5555/#/experiments/1
#
# Extra Trees:
#   RMSE: 23264.94
#   MAE: 14963.73
#   R^2: 0.905
#   CV R^2 (mean ± std): 0.889 ± 0.042
# 🏃 View run Extra Trees at: http://localhost:5555/#/experiments/1/runs/ef2cb85f54314c9ba87674f0f7a438eb
# 🧪 View experiment at: http://localhost:5555/#/experiments/1
#
# ElasticNet:
#   RMSE: 23555.30
#   MAE: 16475.74
#   R^2: 0.903
#   CV R^2 (mean ± std): 0.891 ± 0.039
# 🏃 View run ElasticNet at: http://localhost:5555/#/experiments/1/runs/2be1a1608212494c963d9177239b6a3e
# 🧪 View experiment at: http://localhost:5555/#/experiments/1
#
# Lasso Regression:
#   RMSE: 24117.87
#   MAE: 16792.88
#   R^2: 0.898
#   CV R^2 (mean ± std): 0.867 ± 0.074
# 🏃 View run Lasso Regression at: http://localhost:5555/#/experiments/1/runs/55eb3347b5034ada950d3473641f6be1
# 🧪 View experiment at: http://localhost:5555/#/experiments/1
#
# SVR (Linear):
#   RMSE: 76482.82
#   MAE: 53923.46
#   R^2: -0.024
#   CV R^2 (mean ± std): -0.079 ± 0.070
# 🏃 View run SVR (Linear) at: http://localhost:5555/#/experiments/1/runs/f7f27fcc3e0747688ff72f17067584c8
# 🧪 View experiment at: http://localhost:5555/#/experiments/1

# %% [markdown]
# * **Did you beat the previous approaches?**
#     **No.** The original **Gradient Boosting** model remains the champion ($R^2 \approx 0.918$).
# * **Best New Model:** **Hist Gradient Boosting** came very close ($R^2 \approx 0.909$).
# * **Failures:** **SVR (Linear)** failed completely ($R^2 < 0$), indicating the data requires non-linear modeling or different scaling.

# %% [markdown]
# ## 3. Manual logging with PyTorch

# %% [markdown]
# In this section, we'll implement manual logging for PyTorch models. While scikit-learn has autologging, PyTorch requires manual tracking - giving us full control over what and when to log. MLflow supports autologging for [PyTorch Lightning](https://lightning.ai/docs/pytorch/stable/), but many people prefer or often need low-level control of pure PyTorch. Thus, we will focus on this approach, which also will teach us more about powerful MLflow capabilities.
#
# Note that we need to turn off scikit-learn autologging! Since we are using a Jupyter Notebook, MLflow uses the previously configured autologging unless explicitly turned off.

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
from sklearn.model_selection import KFold

# disable sklearn autologging!
mlflow.sklearn.autolog(disable=True)

mlflow.set_experiment("pytorch-housing-manual")
# Out:
# 2025/11/18 21:03:33 INFO mlflow.tracking.fluent: Experiment with name 'pytorch-housing-manual' does not exist. Creating a new experiment.
# <Experiment: artifact_location='/Users/karol/Studia/sem9/ml-ops-lab05/mlflow-artifacts/2', creation_time=1763496213457, experiment_id='2', last_update_time=1763496213457, lifecycle_stage='active', name='pytorch-housing-manual', tags={}>

# %% [markdown]
# ### 3.1 Targets transformation

# %% [markdown]
# Before training the neural network, we will transform the training target, in order to stabilize the training. To see why, let's plot the house prices:

# %%
y_train.plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# Training on such targets is possible, but very large target values easily risk overflow, particularly when a loss function like mean squared error is used. We will use the log-transform to transform this distribution, as it's near-exponential, so it should bring it closer to normal, and also greatly reduce the values range.
#
# Of course, we will need to transform the network predictions back again to evaluate them!

# %%
y_train_log = np.log1p(y_train)

pd.Series(y_train_log).plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# ### 3.2 Define and train the model

# %% [markdown]
# Since we have tabular data, we will use a simple 2-layer multilayer perceptron (MLP).

# %%
class HousePriceNet(nn.Module):
    def __init__(self, input_dim, hidden_dim=128, dropout_rate=0.2):
        super(HousePriceNet, self).__init__()
        self.fc1 = nn.Linear(input_dim, hidden_dim)
        self.relu = nn.ReLU()
        self.dropout = nn.Dropout(dropout_rate)
        self.fc2 = nn.Linear(hidden_dim, 1)

    def forward(self, x):
        x = self.fc1(x)
        x = self.relu(x)
        x = self.dropout(x)
        x = self.fc2(x)
        return x

# %% [markdown]
# For training, we will check both the 5-fold CV performance, and the traditional train-test split. Cross-validation will give us an additional, robust performance estimation, as well as standard deviation, which is useful for comparing performances of different models. After all, if the difference between models would be within one standard deviation, it wouldn't really be meaningful.

# %%
import torch.nn as nn


class PyTorchTrainer:
    def __init__(self, model_class: type[nn.Module], config: dict):
        self.model_class = model_class
        self.config = config
        self.device = torch.device("mps")

    def create_model(self, input_dim: int) -> nn.Module:
        return self.model_class(
            input_dim=input_dim,
            hidden_dim=self.config["hidden_units"],
            dropout_rate=self.config["dropout"],
        ).to(self.device)

    def create_data_loader(
        self, X: torch.Tensor, y: torch.Tensor, shuffle: bool = True
    ) -> DataLoader:
        dataset = TensorDataset(X, y)
        return DataLoader(
            dataset, batch_size=self.config["batch_size"], shuffle=shuffle
        )

    def train_epoch(
        self,
        model: nn.Module,
        train_loader: DataLoader,
        criterion: nn.Module,
        optimizer: optim.Optimizer,
    ) -> float:
        model.train()
        epoch_loss = 0.0
        batch_count = 0

        for batch_X, batch_y in train_loader:
            optimizer.zero_grad()
            outputs = model(batch_X)
            loss = criterion(outputs, batch_y)
            loss.backward()
            optimizer.step()

            epoch_loss += loss.item()
            batch_count += 1

        return epoch_loss / batch_count

    def train_model(
        self,
        model: nn.Module,
        train_loader: DataLoader,
        epochs: int,
        metric_prefix: str = "",
    ) -> None:
        criterion = nn.MSELoss()
        optimizer = optim.Adam(model.parameters(), lr=self.config["learning_rate"])

        for epoch in range(epochs):
            avg_mse = self.train_epoch(model, train_loader, criterion, optimizer)

            if epoch % self.config["log_interval"] == 0:
                metric_name = (
                    f"{metric_prefix}train_mse" if metric_prefix else "train_mse"
                )
                # manually log metric value, with a given name and step value
                mlflow.log_metric(metric_name, avg_mse, step=epoch)

    @torch.no_grad()
    def evaluate_model(
        self,
        model: nn.Module,
        X: torch.Tensor,
        y_test: torch.Tensor,
        log_prefix: str = "",
    ) -> dict[str, float]:
        model.eval()

        y_pred_norm = model(X)

        # revert the logarithm with exponent
        y_pred = np.expm1(y_pred_norm.detach().cpu().numpy())
        if isinstance(y_test, torch.Tensor):
            y_test = y_test.cpu().numpy()

        rmse = root_mean_squared_error(y_test.ravel(), y_pred.ravel())
        mae = mean_absolute_error(y_test.ravel(), y_pred.ravel())
        r2 = r2_score(y_test.ravel(), y_pred.ravel())

        if log_prefix:
            # manually log metrics that we want
            mlflow.log_metric(f"{log_prefix}_rmse", rmse)
            mlflow.log_metric(f"{log_prefix}_mae", mae)
            mlflow.log_metric(f"{log_prefix}_r2", r2)

        return {"rmse": rmse, "mae": mae, "r2": r2}

    def run_cross_validation(
        self, X_train: torch.Tensor, y_train: torch.Tensor, n_splits: int = 5
    ) -> tuple[float, float, list[float]]:
        kf = KFold(n_splits=n_splits, shuffle=True, random_state=42)
        cv_scores = []

        for fold, (train_idx, val_idx) in enumerate(kf.split(X_train)):
            print(f"\nTraining Fold {fold + 1}/{n_splits}...")

            X_fold_train = X_train[train_idx]
            y_fold_train = y_train[train_idx]
            X_fold_val = X_train[val_idx]
            y_fold_val = y_train[val_idx]

            fold_model = self.create_model(X_train.shape[1])
            fold_loader = self.create_data_loader(X_fold_train, y_fold_train)

            self.train_model(
                fold_model,
                fold_loader,
                self.config["epochs"],
                metric_prefix=f"fold_{fold + 1}_",
            )

            # transform validation data with exponent back to original unit
            y_fold_val = np.expm1(y_fold_val.cpu().numpy())

            val_metrics = self.evaluate_model(
                fold_model, X_fold_val, y_fold_val, log_prefix=f"fold_{fold + 1}_val"
            )

            cv_scores.append(val_metrics["r2"])
            print(
                f"  Fold {fold + 1} "
                f"Validation - RMSE: {val_metrics['rmse']:.2f}, "
                f"MAE: {val_metrics['mae']:.2f} "
                f"R^2: {val_metrics['r2']:.3f}"
            )

        return np.mean(cv_scores), np.std(cv_scores), cv_scores

    def fit(
        self,
        X_train: pd.DataFrame | np.ndarray,
        y_train: pd.Series | np.ndarray,
        X_test: pd.DataFrame | np.ndarray,
        y_test: pd.Series | np.ndarray,
    ) -> dict:
        X_train, X_test, y_train, y_test = self._prepare_tensors(
            X_train, X_test, y_train, y_test
        )

        with mlflow.start_run(run_name=self.config["name"]):
            mlflow.log_params(self.config)

            print(f"Starting 5-fold cross-validation for {self.config['name']}...")
            cv_mean, cv_std, cv_scores = self.run_cross_validation(X_train, y_train)

            mlflow.log_metric("cv_r2_mean", cv_mean)
            mlflow.log_metric("cv_r2_std", cv_std)

            print(
                f"\nCross-validation complete. Mean R^2: {cv_mean:.3f} (+/- {cv_std:.3f})"
            )
            print("\nTraining final model on all training data...")

            final_model = self.create_model(X_train.shape[1])
            final_loader = self.create_data_loader(X_train, y_train)

            self.train_model(
                final_model,
                final_loader,
                self.config["epochs"],
                metric_prefix="final_model_",
            )

            print("\nEvaluating on test set...")
            test_metrics = self.evaluate_model(final_model, X_test, y_test)

            mlflow.log_metric("test_rmse", test_metrics["rmse"])
            mlflow.log_metric("test_mae", test_metrics["mae"])
            mlflow.log_metric("test_r2", test_metrics["r2"])

            self._print_results(test_metrics, cv_mean, cv_std)

            return {
                "rmse": test_metrics["rmse"],
                "mae": test_metrics["mae"],
                "r2": test_metrics["r2"],
                "cv_r2_mean": cv_mean,
                "cv_r2_std": cv_std,
                "cv_scores": cv_scores,
            }

    def _prepare_tensors(self, X_train, X_test, y_train, y_test) -> tuple:
        y_train = np.array(y_train)
        y_test = np.array(y_test)

        X_train_tensor = torch.FloatTensor(X_train).to(self.device)
        y_train_tensor = torch.FloatTensor(y_train.reshape(-1, 1)).to(self.device)
        X_test_tensor = torch.FloatTensor(X_test).to(self.device)
        y_test_tensor = torch.FloatTensor(y_test.reshape(-1, 1)).to(self.device)

        print(f"Training samples: {X_train_tensor.shape[0]}")
        print(f"Input features: {X_train_tensor.shape[1]}")

        return X_train_tensor, X_test_tensor, y_train_tensor, y_test_tensor

    def _print_results(
        self, test_metrics: dict[str, float], cv_mean: float, cv_std: float
    ) -> None:
        print(f"{'=' * 50}\n")
        print(f"  Mean R^2: {cv_mean:.3f} (+/- {cv_std:.3f})")
        print("\nCross-Validation Performance:")
        print(f"  R^2: {test_metrics['r2']:.3f}")
        print(f"  RMSE: {test_metrics['rmse']:.2f}")
        print(f"  MAE: {test_metrics['mae']:.2f}")
        print("Test Set Performance:")
        print(f"{'=' * 50}")
        print(f"FINAL RESULTS for {self.config['name']}:")
        print(f"\n{'=' * 50}")

# %% [markdown]
# Quite a bit of code there! So now let's train the model.

# %%
base_config = {
    "model_class": HousePriceNet,
    "random_seed": 42,
    "log_interval": 5,
    "num_samples": X_train.shape[0],
    "input_features": X_train.shape[1],
    "k_folds": 5,
}

config = {
    "name": "first_run",
    "hidden_units": 128,
    "dropout": 0.1,
    "learning_rate": 0.03,
    "epochs": 150,
    "batch_size": 32,
}

# %%
training_config = base_config | config

trainer = PyTorchTrainer(training_config["model_class"], training_config)
results = trainer.fit(X_train, y_train_log, X_test, y_test)
# Out:
# Training samples: 1312
# Input features: 181
# Starting 5-fold cross-validation for first_run...
#
# Training Fold 1/5...
#   Fold 1 Validation - RMSE: 45981.26, MAE: 34212.30 R^2: 0.707
#
# Training Fold 2/5...
#   Fold 2 Validation - RMSE: 27011.29, MAE: 19181.22 R^2: 0.880
#
# Training Fold 3/5...
#   Fold 3 Validation - RMSE: 36998.08, MAE: 26880.19 R^2: 0.796
#
# Training Fold 4/5...
#   Fold 4 Validation - RMSE: 35983.15, MAE: 22176.50 R^2: 0.773
#
# Training Fold 5/5...
#   Fold 5 Validation - RMSE: 93365.09, MAE: 73651.59 R^2: -0.501
#
# Cross-validation complete. Mean R^2: 0.531 (+/- 0.519)
#
# Training final model on all training data...
#
# Evaluating on test set...
# ==================================================
#
#   Mean R^2: 0.531 (+/- 0.519)
#
# Cross-Validation Performance:
#   R^2: 0.907
#   RMSE: 23081.38
#   MAE: 15894.19
# Test Set Performance:
# ==================================================
# FINAL RESULTS for first_run:
#
# ==================================================
# 🏃 View run first_run at: http://localhost:5555/#/experiments/2/runs/a54109e84b444a3691872f5be9b3a5ac
# 🧪 View experiment at: http://localhost:5555/#/experiments/2

# %% [markdown]
# Go to the MLflow dashboard and take a look at logged values. Focus particularly on the "Model metrics" tab, which for neural networks visualizes the progress of iterative training.

# %% [markdown]
# ### 3.3 Hyperparameter optimization with MLflow

# %% [markdown]
# Now, we will use MLflow logging and visualization capabilities to help us tune hyperparameters of neural networks. This is one of the major applications of experiment tracking frameworks. As neural networks have many hyperparameters, with complex interactions, and training them many times is very computationally intensive, we want to use human judgment, based on plots and metrics, to guide our choices in further experiments.
#
# A quick recap on main hyperparameters of MLPs:
#
# 1. **Learning rate:**
#    - typically 1e-5 to 1e-1
#    - too high: loss explodes, model diverges
#    - too low: slow convergence, might get stuck
#    - sweet spot: fast convergence to good minimum
#
# 3. **Model size** - number of hidden units here:
#    - typically 32 to 512
#    - too few: underfitting, can't capture patterns
#    - too many: overfitting, slow training, diminishing returns
#    - consider: more features need more capacity
#
# 5. **Dropout rate:**
#    - typically 0.0 to 0.5
#    - 0.0: no regularization, risk overfitting
#    - too high: underfitting, loses important information
#    - purpose: prevents over-reliance on specific neurons
#
# 7. **Batch size:**
#    - typically 16 to 128
#    - small: noisy gradients, often better generalization, slower
#    - large: stable gradients, faster training, needs more memory, may overfit
#    - trade-off: speed vs generalization
#
# 9. **Number of epochs:**
#    - too few: underfitting
#    - too many: overfitting
#    - optimal: when validation loss stops improving
#    - watch validation loss

# %% [markdown]
# ### Exercise 2

# %% [markdown]
# Your task is to:
# 1. Run 10 experiments by modifying the hyperparameter configuration. Try to improve model performance, which is currently overfitted.
# 2. Analyze results in MLflow UI.
# 3. Comment on what changes impacted the model performance the most, and what changes disrupted the training process.
# 4. Compare the results of our first scikit-learn configuration with the first PyTorch experiments. Do you see any overfitting in the first PyTorch experiment? Explain what signs of overfitting can indicate this situation.
#
# Example:
#
# ```python
#
# base_config = {
#     # or any other your own architecture :) we definitely recommend to experiment by yourselves
#     "model_class": HousePriceNet,
#     "random_seed": 42,
#     "log_interval": 5,
#     "input_features": X_train.shape[1],
#     "num_samples": X_train.shape[0],
#     "target_normalized": True,
#     "k_folds": 5,
# }
#
# configs = {
#      {
#         "name": "first_run_or_other_your_own_meaningful_name",
#         "hidden_units": 128,
#          ...
#      },
#     {
#         "name": "second_run_or...",
#         "hidden_units": 128,
#         "dropout": 0.1,
#         "learning_rate": 0.03,
#         "epochs": 150,
#         "batch_size": 32,
#     }
# }
#
# for config in configs:
#     # in python we can in elegant way merge two dicts using "|" operator - finally...
#     # old merging method {**base_config, **config} - ugly :(
#     training_config = base_config | config
#     trainer = PyTorchTrainer(training_config["model_class"], preprocessor, training_config)
#     results = trainer.fit(X_train, y_train, X_test, y_test)
# ```
#
# or just manually and incrementally:
#
# ```python
# new_config = {
#     "name": "second_run_or...",
#     "hidden_units": 128,
#     "dropout": 0.1,
#     "learning_rate": 0.03,
#     "epochs": 150,
#     "batch_size": 32,
# }
#
# training_config = base_config | config
# trainer = PyTorchTrainer(training_config["model_class"], preprocessor, training_config)
# results = trainer.fit(X_train, y_train, X_test, y_test)
# ```

# %% [markdown]
# ### Lab assessment
#
# Fill the code exercises in this Jupyter notebook, and send it with completed exercises, written comments in Markdown cells (particularly for questions in exercise 2), and screenshots of results in MLflow.

# %%
base_config = {
    "model_class": HousePriceNet,
    "random_seed": 42,
    "log_interval": 5,
    "num_samples": X_train.shape[0],
    "input_features": X_train.shape[1],
    "k_folds": 5,
}

configs = [
    # Exp 1: Baseline adjustment - Slower Learning Rate
    {
        "name": "exp01_low_lr",
        "hidden_units": 128,
        "dropout": 0.1,
        "learning_rate": 0.001,
        "epochs": 200,
        "batch_size": 32,
    },
    # Exp 2: High Regularization - High Dropout to fight overfitting
    {
        "name": "exp02_high_dropout",
        "hidden_units": 128,
        "dropout": 0.5,
        "learning_rate": 0.03,
        "epochs": 150,
        "batch_size": 32,
    },
    # Exp 3: Reduced Capacity - Smaller Network
    {
        "name": "exp03_small_net",
        "hidden_units": 64,
        "dropout": 0.1,
        "learning_rate": 0.01,
        "epochs": 150,
        "batch_size": 32,
    },
    # Exp 4: Tiny Network - Very small capacity
    {
        "name": "exp04_tiny_net",
        "hidden_units": 32,
        "dropout": 0.0,
        "learning_rate": 0.01,
        "epochs": 150,
        "batch_size": 16,
    },
    # Exp 5: Large Capacity - 256 units (likely to overfit, but good for contrast)
    {
        "name": "exp05_large_net",
        "hidden_units": 256,
        "dropout": 0.4,
        "learning_rate": 0.01,
        "epochs": 150,
        "batch_size": 64,
    },
    # Exp 6: High Stability - Large Batch Size
    {
        "name": "exp06_large_batch",
        "hidden_units": 128,
        "dropout": 0.2,
        "learning_rate": 0.01,
        "epochs": 200,
        "batch_size": 128,
    },
    # Exp 7: "The Patient Learner" - Small LR, Many Epochs, High Dropout
    {
        "name": "exp07_patient",
        "hidden_units": 64,
        "dropout": 0.3,
        "learning_rate": 0.0005,
        "epochs": 400,
        "batch_size": 32,
    },
    # Exp 8: Aggressive Regularization
    {
        "name": "exp08_aggressive_reg",
        "hidden_units": 128,
        "dropout": 0.6,
        "learning_rate": 0.01,
        "epochs": 200,
        "batch_size": 32,
    },
    # Exp 9: Balanced approach
    {
        "name": "exp09_balanced",
        "hidden_units": 96,
        "dropout": 0.25,
        "learning_rate": 0.005,
        "epochs": 200,
        "batch_size": 32,
    },
    # Exp 10: Stochastic - Small Batch Size (Noisier gradients can help generalization)
    {
        "name": "exp10_small_batch",
        "hidden_units": 128,
        "dropout": 0.2,
        "learning_rate": 0.005,
        "epochs": 150,
        "batch_size": 8,
    },
]

print(f"Starting hyperparameter optimization with {len(configs)} experiments...")

for config in configs:
    training_config = base_config | config

    print(f"\nRunning: {training_config['name']}")

    trainer = PyTorchTrainer(training_config["model_class"], training_config)

    trainer.fit(X_train, y_train_log, X_test, y_test)

print("\nAll experiments completed.")
# Out:
# Starting hyperparameter optimization with 10 experiments...
#
# Running: exp01_low_lr
# Training samples: 1312
# Input features: 181
# Starting 5-fold cross-validation for exp01_low_lr...
#
# Training Fold 1/5...
#   Fold 1 Validation - RMSE: 39383.02, MAE: 29875.79 R^2: 0.785
#
# Training Fold 2/5...
#   Fold 2 Validation - RMSE: 59574.53, MAE: 35320.36 R^2: 0.418
#
# Training Fold 3/5...
#   Fold 3 Validation - RMSE: 47206.38, MAE: 34401.79 R^2: 0.668
#
# Training Fold 4/5...
#   Fold 4 Validation - RMSE: 57891.82, MAE: 37364.57 R^2: 0.413
#
# Training Fold 5/5...
#   Fold 5 Validation - RMSE: 43245.16, MAE: 32086.41 R^2: 0.678
#
# Cross-validation complete. Mean R^2: 0.593 (+/- 0.150)
#
# Training final model on all training data...
#
# Evaluating on test set...
# ==================================================
#
#   Mean R^2: 0.593 (+/- 0.150)
#
# Cross-Validation Performance:
#   R^2: 0.435
#   RMSE: 56836.79
#   MAE: 40176.35
# Test Set Performance:
# ==================================================
# FINAL RESULTS for exp01_low_lr:
#
# ==================================================
# 🏃 View run exp01_low_lr at: http://localhost:5555/#/experiments/2/runs/186ac4b56c6e4e478447bac076395d1c
# 🧪 View experiment at: http://localhost:5555/#/experiments/2
#
# Running: exp02_high_dropout
# Training samples: 1312
# Input features: 181
# Starting 5-fold cross-validation for exp02_high_dropout...
#
# Training Fold 1/5...
#   Fold 1 Validation - RMSE: 33662.30, MAE: 23420.58 R^2: 0.843
#
# Training Fold 2/5...
#   Fold 2 Validation - RMSE: 25077.95, MAE: 16665.83 R^2: 0.897
#
# Training Fold 3/5...
#   Fold 3 Validation - RMSE: 24332.11, MAE: 16240.53 R^2: 0.912
#
# Training Fold 4/5...
#   Fold 4 Validation - RMSE: 24307.36, MAE: 16468.82 R^2: 0.897
#
# Training Fold 5/5...
#   Fold 5 Validation - RMSE: 34602.93, MAE: 25300.32 R^2: 0.794
#
# Cross-validation complete. Mean R^2: 0.868 (+/- 0.044)
#
# Training final model on all training data...
#
# Evaluating on test set...
# ==================================================
#
#   Mean R^2: 0.868 (+/- 0.044)
#
# Cross-Validation Performance:
#   R^2: 0.846
#   RMSE: 29631.21
#   MAE: 20151.54
# Test Set Performance:
# ==================================================
# FINAL RESULTS for exp02_high_dropout:
#
# ==================================================
# 🏃 View run exp02_high_dropout at: http://localhost:5555/#/experiments/2/runs/0d8f4dea08374ff9a4b072310d51a5f2
# 🧪 View experiment at: http://localhost:5555/#/experiments/2
#
# Running: exp03_small_net
# Training samples: 1312
# Input features: 181
# Starting 5-fold cross-validation for exp03_small_net...
#
# Training Fold 1/5...
#   Fold 1 Validation - RMSE: 37346.60, MAE: 28203.03 R^2: 0.807
#
# Training Fold 2/5...
#   Fold 2 Validation - RMSE: 80370.29, MAE: 63212.96 R^2: -0.059
#
# Training Fold 3/5...
#   Fold 3 Validation - RMSE: 43363.70, MAE: 32037.50 R^2: 0.720
#
# Training Fold 4/5...
#   Fold 4 Validation - RMSE: 45309.11, MAE: 25989.19 R^2: 0.641
#
# Training Fold 5/5...
#   Fold 5 Validation - RMSE: 35206.68, MAE: 26944.15 R^2: 0.787
#
# Cross-validation complete. Mean R^2: 0.579 (+/- 0.324)
#
# Training final model on all training data...
#
# Evaluating on test set...
# ==================================================
#
#   Mean R^2: 0.579 (+/- 0.324)
#
# Cross-Validation Performance:
#   R^2: 0.568
#   RMSE: 49691.78
#   MAE: 38715.19
# Test Set Performance:
# ==================================================
# FINAL RESULTS for exp03_small_net:
#
# ==================================================
# 🏃 View run exp03_small_net at: http://localhost:5555/#/experiments/2/runs/33a69491ca804d6c9ec7488fa49f1034
# 🧪 View experiment at: http://localhost:5555/#/experiments/2
#
# Running: exp04_tiny_net
# Training samples: 1312
# Input features: 181
# Starting 5-fold cross-validation for exp04_tiny_net...
#
# Training Fold 1/5...
#   Fold 1 Validation - RMSE: 47222.55, MAE: 34057.99 R^2: 0.691
#
# Training Fold 2/5...
#   Fold 2 Validation - RMSE: 57274.52, MAE: 41286.99 R^2: 0.462
#
# Training Fold 3/5...
#   Fold 3 Validation - RMSE: 39105.15, MAE: 30550.92 R^2: 0.772
#
# Training Fold 4/5...
#   Fold 4 Validation - RMSE: 51692.39, MAE: 32231.46 R^2: 0.532
#
# Training Fold 5/5...
#   Fold 5 Validation - RMSE: 38767.94, MAE: 27310.80 R^2: 0.741
#
# Cross-validation complete. Mean R^2: 0.640 (+/- 0.121)
#
# Training final model on all training data...
#
# Evaluating on test set...
# ==================================================
#
#   Mean R^2: 0.640 (+/- 0.121)
#
# Cross-Validation Performance:
#   R^2: 0.717
#   RMSE: 40177.96
#   MAE: 24584.85
# Test Set Performance:
# ==================================================
# FINAL RESULTS for exp04_tiny_net:
#
# ==================================================
# 🏃 View run exp04_tiny_net at: http://localhost:5555/#/experiments/2/runs/bd32b0c07254453db5ab138ad7202cab
# 🧪 View experiment at: http://localhost:5555/#/experiments/2
#
# Running: exp05_large_net
# Training samples: 1312
# Input features: 181
# Starting 5-fold cross-validation for exp05_large_net...
#
# Training Fold 1/5...
#   Fold 1 Validation - RMSE: 52012.98, MAE: 36022.94 R^2: 0.625
#
# Training Fold 2/5...
#   Fold 2 Validation - RMSE: 51222.33, MAE: 35931.55 R^2: 0.570
#
# Training Fold 3/5...
#   Fold 3 Validation - RMSE: 54606.53, MAE: 42417.55 R^2: 0.556
#
# Training Fold 4/5...
#   Fold 4 Validation - RMSE: 63465.20, MAE: 37658.31 R^2: 0.295
#
# Training Fold 5/5...
#   Fold 5 Validation - RMSE: 62362.84, MAE: 45709.04 R^2: 0.330
#
# Cross-validation complete. Mean R^2: 0.475 (+/- 0.135)
#
# Training final model on all training data...
#
# Evaluating on test set...
# ==================================================
#
#   Mean R^2: 0.475 (+/- 0.135)
#
# Cross-Validation Performance:
#   R^2: 0.501
#   RMSE: 53409.98
#   MAE: 36240.94
# Test Set Performance:
# ==================================================
# FINAL RESULTS for exp05_large_net:
#
# ==================================================
# 🏃 View run exp05_large_net at: http://localhost:5555/#/experiments/2/runs/e5910bd45b5d4648a362e7b5235e130b
# 🧪 View experiment at: http://localhost:5555/#/experiments/2
#
# Running: exp06_large_batch
# Training samples: 1312
# Input features: 181
# Starting 5-fold cross-validation for exp06_large_batch...
#
# Training Fold 1/5...
#   Fold 1 Validation - RMSE: 68539.17, MAE: 48919.09 R^2: 0.349
#
# Training Fold 2/5...
#   Fold 2 Validation - RMSE: 56072.33, MAE: 39321.06 R^2: 0.485
#
# Training Fold 3/5...
#   Fold 3 Validation - RMSE: 87624.39, MAE: 63945.19 R^2: -0.144
#
# Training Fold 4/5...
#   Fold 4 Validation - RMSE: 57178.30, MAE: 40063.07 R^2: 0.428
#
# Training Fold 5/5...
#   Fold 5 Validation - RMSE: 54345.09, MAE: 43339.45 R^2: 0.492
#
# Cross-validation complete. Mean R^2: 0.322 (+/- 0.238)
#
# Training final model on all training data...
#
# Evaluating on test set...
# ==================================================
#
#   Mean R^2: 0.322 (+/- 0.238)
#
# Cross-Validation Performance:
#   R^2: -0.565
#   RMSE: 94556.26
#   MAE: 71085.09
# Test Set Performance:
# ==================================================
# FINAL RESULTS for exp06_large_batch:
#
# ==================================================
# 🏃 View run exp06_large_batch at: http://localhost:5555/#/experiments/2/runs/2735f3050b9148e18c415ef0156a66fb
# 🧪 View experiment at: http://localhost:5555/#/experiments/2
#
# Running: exp07_patient
# Training samples: 1312
# Input features: 181
# Starting 5-fold cross-validation for exp07_patient...
#
# Training Fold 1/5...
#   Fold 1 Validation - RMSE: 53511.33, MAE: 42467.29 R^2: 0.603
#
# Training Fold 2/5...
#   Fold 2 Validation - RMSE: 41307.55, MAE: 30502.18 R^2: 0.720
#
# Training Fold 3/5...
#   Fold 3 Validation - RMSE: 39850.11, MAE: 29326.53 R^2: 0.763
#
# Training Fold 4/5...
#   Fold 4 Validation - RMSE: 49250.98, MAE: 35050.69 R^2: 0.575
#
# Training Fold 5/5...
#   Fold 5 Validation - RMSE: 53693.80, MAE: 43469.64 R^2: 0.504
#
# Cross-validation complete. Mean R^2: 0.633 (+/- 0.095)
#
# Training final model on all training data...
#
# Evaluating on test set...
# ==================================================
#
#   Mean R^2: 0.633 (+/- 0.095)
#
# Cross-Validation Performance:
#   R^2: 0.635
#   RMSE: 45666.89
#   MAE: 35365.04
# Test Set Performance:
# ==================================================
# FINAL RESULTS for exp07_patient:
#
# ==================================================
# 🏃 View run exp07_patient at: http://localhost:5555/#/experiments/2/runs/629a93ff8f1a472480a5ee641fc7654c
# 🧪 View experiment at: http://localhost:5555/#/experiments/2
#
# Running: exp08_aggressive_reg
# Training samples: 1312
# Input features: 181
# Starting 5-fold cross-validation for exp08_aggressive_reg...
#
# Training Fold 1/5...
#   Fold 1 Validation - RMSE: 25501.61, MAE: 17373.20 R^2: 0.910
#
# Training Fold 2/5...
#   Fold 2 Validation - RMSE: 28314.40, MAE: 20053.79 R^2: 0.869
#
# Training Fold 3/5...
#   Fold 3 Validation - RMSE: 25193.88, MAE: 16464.40 R^2: 0.905
#
# Training Fold 4/5...
#   Fold 4 Validation - RMSE: 30793.78, MAE: 22348.24 R^2: 0.834
#
# Training Fold 5/5...
#   Fold 5 Validation - RMSE: 24731.96, MAE: 17251.00 R^2: 0.895
#
# Cross-validation complete. Mean R^2: 0.883 (+/- 0.028)
#
# Training final model on all training data...
#
# Evaluating on test set...
# ==================================================
#
#   Mean R^2: 0.883 (+/- 0.028)
#
# Cross-Validation Performance:
#   R^2: 0.834
#   RMSE: 30815.30
#   MAE: 22751.57
# Test Set Performance:
# ==================================================
# FINAL RESULTS for exp08_aggressive_reg:
#
# ==================================================
# 🏃 View run exp08_aggressive_reg at: http://localhost:5555/#/experiments/2/runs/48e03bcf6911439c943673780ece5cf8
# 🧪 View experiment at: http://localhost:5555/#/experiments/2
#
# Running: exp09_balanced
# Training samples: 1312
# Input features: 181
# Starting 5-fold cross-validation for exp09_balanced...
#
# Training Fold 1/5...
#   Fold 1 Validation - RMSE: 33566.06, MAE: 24107.19 R^2: 0.844
#
# Training Fold 2/5...
#   Fold 2 Validation - RMSE: 35720.59, MAE: 25966.53 R^2: 0.791
#
# Training Fold 3/5...
#   Fold 3 Validation - RMSE: 31956.90, MAE: 23416.61 R^2: 0.848
#
# Training Fold 4/5...
#   Fold 4 Validation - RMSE: 34712.78, MAE: 22877.11 R^2: 0.789
#
# Training Fold 5/5...
#   Fold 5 Validation - RMSE: 36285.38, MAE: 25877.57 R^2: 0.773
#
# Cross-validation complete. Mean R^2: 0.809 (+/- 0.031)
#
# Training final model on all training data...
#
# Evaluating on test set...
# ==================================================
#
#   Mean R^2: 0.809 (+/- 0.031)
#
# Cross-Validation Performance:
#   R^2: 0.745
#   RMSE: 38143.56
#   MAE: 28239.01
# Test Set Performance:
# ==================================================
# FINAL RESULTS for exp09_balanced:
#
# ==================================================
# 🏃 View run exp09_balanced at: http://localhost:5555/#/experiments/2/runs/e0a6666c84ed444ea44ecfb86a9353d8
# 🧪 View experiment at: http://localhost:5555/#/experiments/2
#
# Running: exp10_small_batch
# Training samples: 1312
# Input features: 181
# Starting 5-fold cross-validation for exp10_small_batch...
#
# Training Fold 1/5...
#   Fold 1 Validation - RMSE: 24271.57, MAE: 18102.04 R^2: 0.918
#
# Training Fold 2/5...
#   Fold 2 Validation - RMSE: 30975.09, MAE: 22988.47 R^2: 0.843
#
# Training Fold 3/5...
#   Fold 3 Validation - RMSE: 32510.85, MAE: 22214.80 R^2: 0.843
#
# Training Fold 4/5...
#   Fold 4 Validation - RMSE: 24091.96, MAE: 16609.32 R^2: 0.898
#
# Training Fold 5/5...
#   Fold 5 Validation - RMSE: 36238.69, MAE: 27772.60 R^2: 0.774
#
# Cross-validation complete. Mean R^2: 0.855 (+/- 0.051)
#
# Training final model on all training data...
#
# Evaluating on test set...
# ==================================================
#
#   Mean R^2: 0.855 (+/- 0.051)
#
# Cross-Validation Performance:
#   R^2: 0.873
#   RMSE: 26935.34
#   MAE: 18628.24
# Test Set Performance:
# ==================================================
# FINAL RESULTS for exp10_small_batch:
#
# ==================================================
# 🏃 View run exp10_small_batch at: http://localhost:5555/#/experiments/2/runs/a3456d60f9834faa82d352d625cc7a6a
# 🧪 View experiment at: http://localhost:5555/#/experiments/2
#
# All experiments completed.

# %% [markdown]
# **1. Analysis & Impact**
# * **Best Stability:** `exp08_aggressive_reg` (High Dropout). It reduced CV standard deviation from $\pm 0.52$ to $\pm 0.03$.
# * **Best Test Score:** `exp10_small_batch` ($R^2 \approx 0.873$). Small batches added noise that helped the model generalize better.
# * **Most Critical Parameter:** **Dropout**. Increasing it from 0.1 to 0.5+ was essential to stop the model from memorizing the training data.
# * **Worst Parameter:** **Large Batch Size** (128) caused the model to get stuck in poor local minima (`exp06`).
#
# **2. Overfitting & Comparison**
# * **Was the first PyTorch run overfitted?**
#     **Yes, severely.**
# * **Evidence:**
#     1.  **Extreme Variance:** The Cross-Validation $R^2$ standard deviation was massive ($\pm 0.519$), meaning the model worked great on some folds and failed miserably on others.
#     2.  **Score Gap:** The Test score (0.907) was much higher than the CV mean (0.531), suggesting the model got "lucky" on the test split rather than learning robust rules like the Scikit-Learn models did.

# %% [markdown]
# ### MLflow screenshots
#
# ![img1](imgs/img1.png)
# ![img2](imgs/img2.png)
# ![img3](imgs/img3.png)
# ![img4](imgs/img4.png)
